# %%
from load_data import data_loader

fa, func, gm = data_loader()
# Out:
# Extracting all the files now...
# Done!

# %%
fa
# Out:
#           ctx-lh-caudalanteriorcingulate/ctx-lh-caudalmiddlefrontal  \
# 002MSVIS                                           0.395567
# 003MSVIS                                           0.330618
# 004MSVIS                                           0.418653
# 005MSVIS                                           0.378885
# 010MSVIS                                           0.354844
# ...                                                     ...
# sFIS_04                                            0.437912
# sFIS_05                                            0.453001
# sFIS_06                                            0.444399
# sFIS_07                                            0.486600
# sFIS_09                                            0.460415
#
#           ctx-lh-caudalanteriorcingulate/ctx-lh-cuneus  \
# 002MSVIS                                      0.000000
# 003MSVIS                                      0.000000
# 004MSVIS                                      0.000000
# ...
